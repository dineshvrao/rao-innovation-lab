# %%
# Databricks Notebook: customer_sales_demo.py

from pyspark.sql.functions import col, sum, count, round, when

# 1. Create sample data
data = [
    (1, "Alice", "East", "Laptop", 1200, 1),
    (2, "Bob", "West", "Monitor", 300, 2),
    (3, "Charlie", "East", "Keyboard", 80, 3),
    (4, "David", "South", "Laptop", 1200, 1),
    (5, "Emma", "West", "Mouse", 40, 5),
]

columns = ["order_id", "customer_name", "region", "product", "unit_price", "quantity"]

df = spark.createDataFrame(data, columns)

display(df)
